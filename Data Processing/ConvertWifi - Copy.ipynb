# %%
import pandas as pd
df = pd.DataFrame()
import csv
from scipy.stats import zscore
import numpy as np

# %% [markdown]
# ## Extract data from raw text wifi log file

# %%
#Create csv file
jan1_csv = open('jan1.csv', 'w')
#Column names
col_name = ['building', 'date', 'month', 'time', 'device_count']
csv_writer = csv.DictWriter(jan1_csv, fieldnames=col_name)
csv_writer.writeheader()
# Out:
# 39

# %%
def processLine(wifi_log=''):
    
    #Make a Dict that stores the count for each building
    building_count = {}
    
    for buildingName in selected_buildings:
        building_count[buildingName] = 0

    for log_line in wifi_log:
        if buildingName in log_line:
            # process device count
            if '501080' in log_line or '501105' in log_line or '501106' in log_line:
                count += 0
            if '501093' in log_line:
                count += 1
            # Slice the line to get the date and time
            atr = log_line.split(' ')
            # Extract the data
            month = atr[0]
            date = atr[1]
            time = atr[2]
            building = buildingName
            # add data to csv file
            csv_writer.writerow({'building': building, 'date': date, 'month': month, 'time': time, 'device_count': count})

# %%
#No need to run this unless the date is new or building is added / removed

wifi_log = open(raw_file, 'r')
# # print first ten lines in the file
# for i in range(3):
#     print(wifi_log.readline())

# loop through each line in the file
processLine(wifi_log=wifi_log)

# close the file
wifi_log.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4012\2551500058.py in <module>
#       7
#       8 # loop through each line in the file
# ----> 9 processLine(wifi_log=wifi_log)
#      10
#      11 # close the file
#
# ~\AppData\Local\Temp\ipykernel_4012\3467900617.py in processLine(wifi_log)
#       7         building_count[buildingName] = 0
#       8
# ----> 9     for log_line in wifi_log:
#      10         for buildingName in selected_buildings:
#      11             if buildingName in log_line:
#
# c:\ProgramData\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
# ---> 22     def decode(self, input, final=False):
#      23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#
# KeyboardInterrupt:

# %% [markdown]
# # Preprocess the raw csv to something meaningful (non-scalable)

# %% [markdown]
# ### Look at the dataframe

# %%
# Look look at the data
# convert jan1.csv to dataframe
df = pd.read_csv('jan1.csv')
df
# Out:
#         building  date month      time  device_count
# 0           UREC    21   Sep  00:00:11             1
# 1           UREC    21   Sep  00:00:11             1
# 2           UREC    21   Sep  00:00:11             1
# 3           UREC    21   Sep  00:00:11             1
# 4           UREC    21   Sep  00:00:11             1
# ...          ...   ...   ...       ...           ...
# 1057200     UREC    21   Sep  23:59:47        172702
# 1057201     UREC    21   Sep  23:59:47        172702
# 1057202     UREC    21   Sep  23:59:47        172702
# 1057203     UREC    21   Sep  23:59:59        172702
# 1057204     UREC    21   Sep  23:59:59        172702
#
# [1057205 rows x 5 columns]

# %% [markdown]
# ### Process the time columns into a timestamp column

# %%
# convert time to datetime
df['timestamp'] = pd.to_datetime(df['time'])
# get type of time column
print('timestamp column type: ', df['timestamp'].dtype)
# diplay from time 00:00:00 to 00:00:59
df1 = df.loc[(df['timestamp'] >= '17:00:00') & (df['timestamp'] <= '18:00:00')]
# drop date and month column
df1 = df1.drop(['date', 'month', 'time'], axis=1)
df1
# Out:
# timestamp column type:  datetime64[ns]
#        building  device_count           timestamp
# 592572     UREC         97763 2022-11-07 17:00:00
# 592573     UREC         97763 2022-11-07 17:00:00
# 592574     UREC         97763 2022-11-07 17:00:00
# 592575     UREC         97763 2022-11-07 17:00:00
# 592576     UREC         97764 2022-11-07 17:00:00
# ...         ...           ...                 ...
# 690366     UREC        113779 2022-11-07 18:00:00
# 690367     UREC        113780 2022-11-07 18:00:00
# 690368     UREC        113780 2022-11-07 18:00:00
# 690369     UREC        113780 2022-11-07 18:00:00
# 690370     UREC        113780 2022-11-07 18:00:00
#
# [97799 rows x 3 columns]

# %%
count = 0
dfTrim = pd.DataFrame()

while count < 24:
    startTime = ''
    endTime = ''

    if count < 10:
        startTime = pd.to_datetime('0' + str(count) + ':00:00')
        endTime = pd.to_datetime('0' + str(count) + ':59:59')
    else:
        startTime = pd.to_datetime(str(count) + ':00:00')
        endTime = pd.to_datetime(str(count) + ':59:59')

    df1 = df.loc[(df['timestamp'] >= startTime) & (df['timestamp'] <= endTime )]
    dfTrim = dfTrim.append(df1.iloc[1])
    count += 1


dfTrim = dfTrim.reset_index()
dfTrim
# Out:
# Dataframe for UREC:
#       index building  date  device_count month      time           timestamp
# 0         1     UREC  21.0           1.0   Sep  00:00:11 2022-11-07 00:00:11
# 1      1500     UREC  21.0         250.0   Sep  01:00:08 2022-11-07 01:00:08
# 2      3258     UREC  21.0         542.0   Sep  02:00:03 2022-11-07 02:00:03
# 3      3788     UREC  21.0         629.0   Sep  03:00:02 2022-11-07 03:00:02
# 4      4223     UREC  21.0         700.0   Sep  04:00:23 2022-11-07 04:00:23
# 5      4549     UREC  21.0         752.0   Sep  05:00:09 2022-11-07 05:00:09
# 6      6763     UREC  21.0        1121.0   Sep  06:00:02 2022-11-07 06:00:02
# 7     23777     UREC  21.0        3795.0   Sep  07:00:00 2022-11-07 07:00:00
# 8     52630     UREC  21.0        8342.0   Sep  08:00:00 2022-11-07 08:00:00
# 9     93892     UREC  21.0       15083.0   Sep  09:00:00 2022-11-07 09:00:00
# 10   142042     UREC  21.0       23173.0   Sep  10:00:00 2022-11-07 10:00:00
# 11   179539     UREC  21.0       29271.0   Sep  11:00:00 2022-11-07 11:00:00
# 12   237688     UREC  21.0       38999.0   Sep  12:00:00 2022-11-07 12:00:00
# 13   303999     UREC  21.0       50255.0   Sep  13:00:00 2022-11-07 13:00:00
# 14   361208     UREC  21.0       59599.0   Sep  14:00:00 2022-11-07 14:00:00
# 15   437867     UREC  21.0       72523.0   Sep  15:00:01 2022-11-07 15:00:01
# 16   514386     UREC  21.0       85153.0   Sep  16:00:00 2022-11-07 16:00:00
# 17   592573     UREC  21.0       97763.0   Sep  17:00:00 2022-11-07 17:00:00
# 18   690357     UREC  21.0      113778.0   Sep  18:00:00 2022-11-07 18:00:00
# 19   781982     UREC  21.0      128476.0   Sep  19:00:00 2022-11-07 19:00:00
# 20   857994     UREC  21.0      140717.0   Sep  20:00:00 2022-11-07 20:00:00
# 21   945794     UREC  21.0      154936.0   Sep  21:00:00 2022-11-07 21:00:00
# 22  1015036     UREC  21.0      165968.0   Sep  22:00:00 2022-11-07 22:00:00
# 23  1051112     UREC  21.0      171704.0   Sep  23:00:00 2022-11-07 23:00:00

# %%
dfTrim['traffic_diff'] = dfTrim['device_count'].diff(periods=1)
dfTrim
# Out:
#       index building  date  device_count month      time           timestamp  \
# 0         1     UREC  21.0           1.0   Sep  00:00:11 2022-11-07 00:00:11
# 1      1500     UREC  21.0         250.0   Sep  01:00:08 2022-11-07 01:00:08
# 2      3258     UREC  21.0         542.0   Sep  02:00:03 2022-11-07 02:00:03
# 3      3788     UREC  21.0         629.0   Sep  03:00:02 2022-11-07 03:00:02
# 4      4223     UREC  21.0         700.0   Sep  04:00:23 2022-11-07 04:00:23
# 5      4549     UREC  21.0         752.0   Sep  05:00:09 2022-11-07 05:00:09
# 6      6763     UREC  21.0        1121.0   Sep  06:00:02 2022-11-07 06:00:02
# 7     23777     UREC  21.0        3795.0   Sep  07:00:00 2022-11-07 07:00:00
# 8     52630     UREC  21.0        8342.0   Sep  08:00:00 2022-11-07 08:00:00
# 9     93892     UREC  21.0       15083.0   Sep  09:00:00 2022-11-07 09:00:00
# 10   142042     UREC  21.0       23173.0   Sep  10:00:00 2022-11-07 10:00:00
# 11   179539     UREC  21.0       29271.0   Sep  11:00:00 2022-11-07 11:00:00
# 12   237688     UREC  21.0       38999.0   Sep  12:00:00 2022-11-07 12:00:00
# 13   303999     UREC  21.0       50255.0   Sep  13:00:00 2022-11-07 13:00:00
# 14   361208     UREC  21.0       59599.0   Sep  14:00:00 2022-11-07 14:00:00
# 15   437867     UREC  21.0       72523.0   Sep  15:00:01 2022-11-07 15:00:01
# 16   514386     UREC  21.0       85153.0   Sep  16:00:00 2022-11-07 16:00:00
# 17   592573     UREC  21.0       97763.0   Sep  17:00:00 2022-11-07 17:00:00
# 18   690357     UREC  21.0      113778.0   Sep  18:00:00 2022-11-07 18:00:00
# 19   781982     UREC  21.0      128476.0   Sep  19:00:00 2022-11-07 19:00:00
# 20   857994     UREC  21.0      140717.0   Sep  20:00:00 2022-11-07 20:00:00
# 21   945794     UREC  21.0      154936.0   Sep  21:00:00 2022-11-07 21:00:00
# 22  1015036     UREC  21.0      165968.0   Sep  22:00:00 2022-11-07 22:00:00
# 23  1051112     UREC  21.0      171704.0   Sep  23:00:00 2022-11-07 23:00:00
#
#     traffic_diff
# 0            NaN
# 1          249.0
# 2          292.0
# 3           87.0
# 4           71.0
# 5           52.0
# 6          369.0
# 7         2674.0
# 8         4547.0
# 9         6741.0
# 10        8090.0
# 11        6098.0
# 12        9728.0
# 13       11256.0
# 14        9344.0
# 15       12924.0
# 16       12630.0
# 17       12610.0
# 18       16015.0
# 19       14698.0
# 20       12241.0
# 21       14219.0
# 22       11032.0
# 23        5736.0

# %%
dfTrim['traffic_diff'] = dfTrim['traffic_diff'].replace(np.nan, 0)
dfTrim['traffic_diff_zscore'] = zscore(dfTrim['traffic_diff'])
print(dfTrim['traffic_diff'].dtype)
dfTrim
# Out:
# float64
#       index building  date  device_count month      time           timestamp  \
# 0         1     UREC  21.0           1.0   Sep  00:00:11 2022-11-07 00:00:11
# 1      1500     UREC  21.0         250.0   Sep  01:00:08 2022-11-07 01:00:08
# 2      3258     UREC  21.0         542.0   Sep  02:00:03 2022-11-07 02:00:03
# 3      3788     UREC  21.0         629.0   Sep  03:00:02 2022-11-07 03:00:02
# 4      4223     UREC  21.0         700.0   Sep  04:00:23 2022-11-07 04:00:23
# 5      4549     UREC  21.0         752.0   Sep  05:00:09 2022-11-07 05:00:09
# 6      6763     UREC  21.0        1121.0   Sep  06:00:02 2022-11-07 06:00:02
# 7     23777     UREC  21.0        3795.0   Sep  07:00:00 2022-11-07 07:00:00
# 8     52630     UREC  21.0        8342.0   Sep  08:00:00 2022-11-07 08:00:00
# 9     93892     UREC  21.0       15083.0   Sep  09:00:00 2022-11-07 09:00:00
# 10   142042     UREC  21.0       23173.0   Sep  10:00:00 2022-11-07 10:00:00
# 11   179539     UREC  21.0       29271.0   Sep  11:00:00 2022-11-07 11:00:00
# 12   237688     UREC  21.0       38999.0   Sep  12:00:00 2022-11-07 12:00:00
# 13   303999     UREC  21.0       50255.0   Sep  13:00:00 2022-11-07 13:00:00
# 14   361208     UREC  21.0       59599.0   Sep  14:00:00 2022-11-07 14:00:00
# 15   437867     UREC  21.0       72523.0   Sep  15:00:01 2022-11-07 15:00:01
# 16   514386     UREC  21.0       85153.0   Sep  16:00:00 2022-11-07 16:00:00
# 17   592573     UREC  21.0       97763.0   Sep  17:00:00 2022-11-07 17:00:00
# 18   690357     UREC  21.0      113778.0   Sep  18:00:00 2022-11-07 18:00:00
# 19   781982     UREC  21.0      128476.0   Sep  19:00:00 2022-11-07 19:00:00
# 20   857994     UREC  21.0      140717.0   Sep  20:00:00 2022-11-07 20:00:00
# 21   945794     UREC  21.0      154936.0   Sep  21:00:00 2022-11-07 21:00:00
# 22  1015036     UREC  21.0      165968.0   Sep  22:00:00 2022-11-07 22:00:00
# 23  1051112     UREC  21.0      171704.0   Sep  23:00:00 2022-11-07 23:00:00
#
#     traffic_diff  traffic_diff_zscore
# 0            0.0            -1.305168
# 1          249.0            -1.259743
# 2          292.0            -1.251898
# 3           87.0            -1.289297
# 4           71.0            -1.292216
# 5           52.0            -1.295682
# 6          369.0            -1.237851
# 7         2674.0            -0.817346
# 8         4547.0            -0.475652
# 9         6741.0            -0.075397
# 10        8090.0             0.170703
# 11        6098.0            -0.192701
# 12        9728.0             0.469526
# 13       11256.0             0.748281
# 14        9344.0             0.399472
# 15       12924.0             1.052577
# 16       12630.0             0.998942
# 17       12610.0             0.995293
# 18       16015.0             1.616473
# 19       14698.0             1.376210
# 20       12241.0             0.927976
# 21       14219.0             1.288826
# 22       11032.0             0.707416
# 23        5736.0            -0.258741

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# bar graph
#plt.bar(dfTrim.index, dfTrim['traffic_diff_zscore'])
#plt.show()

# plot each building data in different graphs
for building, df in trim_df.items():
    plt.figure(figsize=(20,5))
    plt.title(building)
    plt.xlabel('Hour')
    plt.ylabel('Traffic Difference')
    plt.bar(df.index, df['traffic_diff'])
    plt.show()
